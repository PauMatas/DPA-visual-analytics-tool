# %%
import pandas as pd
import altair as alt
import numpy as np

from Modules import Run

# %%
run = Run('../data/20221216_Run1.csv')

# %%
run.describe()
# Out:
#            TimeStamp      Throttle      Steering         VN_ax         VN_ay  \
# count   18864.000000  18864.000000  18864.000000  18864.000000  18864.000000
# mean    94310.251222     31.526987      0.048392     -0.957461      1.826356
# std     54457.127915     35.524136      0.177471      2.092705      6.964562
# min         0.058000      0.000000     -0.426924     -7.920232    -21.468046
# 25%     47152.674250      0.000000     -0.087528     -2.245294     -0.762588
# 50%     94310.635000     15.740459      0.033940     -0.605040     -0.013533
# 75%    141467.691750     53.531311      0.180416     -0.079545      7.765290
# max    188625.216000    100.000000      0.448359      5.973810     18.944254
#
#           xPosition     yPosition     zPosition     xVelocity     yVelocity  \
# count  18864.000000  18864.000000  18864.000000  18864.000000  18864.000000
# mean       5.517115     -9.948253     -0.094167      7.412140      0.036912
# ...

# %%
run.laps
# Out:
# [[Lap 0] 0.0s -> Matas,
#  [Lap 1] 28.660200119018555s -> Matas,
#  [Lap 2] 30.63189697265625s -> Matas,
#  [Lap 3] 22.884031295776367s -> Rodas,
#  [Lap 4] 21.960426330566406s -> Matas,
#  [Lap 5] 21.93149185180664s -> Matas,
#  [Lap 6] 22.59998893737793s -> Matas]

# %%
run.laps[2].gg_diagram()
# Out:
# /usr/local/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
run.laps[2].positions_chart()
# Out:
# /usr/local/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.LayerChart(...)
