# %%
import pandas as pd
import altair as alt
import numpy as np

from Modules import Run

alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
run = (
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run3.csv', 'Rueda') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run4.csv', 'Rueda') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run5.csv', 'Arnau') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run6.csv', 'Arnau') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run7.csv', 'Boix') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run9.csv', 'Boix') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run10.csv', 'Gil') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run11.csv', 'Gil') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run12.csv', 'Rodas') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run13.csv', 'Rodas') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run14.csv', 'Rodas') +
    Run('../data/2022-12-20-Pilots/CSV/20221220_Run15.csv', 'Jordi')
)

# %%
run.describe()
# Out:
#            TimeStamp      Throttle      Steering         VN_ax         VN_ay  \
# count   67192.000000  67192.000000  67192.000000  67192.000000  67192.000000
# mean    34272.820248     39.863711      0.009342     -0.898362     -0.261613
# std     29685.417563     44.650676      0.182311      2.444781      6.380316
# min         0.040000      0.000000     -0.455505    -12.803527    -19.964167
# 25%     13984.946500      0.000000     -0.041085     -2.001849     -3.331477
# 50%     27983.427500      9.100254      0.062520     -0.683638     -0.196003
# 75%     42343.791250    100.000000      0.083956      0.965591      2.217098
# max    141802.635000    100.000000      0.448359      6.706781     20.229422
#
#           xPosition     yPosition     zPosition     xVelocity     yVelocity  \
# count  67192.000000  67192.000000  67192.000000  67192.000000  67192.000000
# mean      12.232437     -6.864398      0.198479      6.833095     -0.015490
# ...

# %%
run.laps
# Out:
# [[Lap 0] 0.0s -> Rueda,
#  [Lap 1] 35.46390151977539s -> Rueda,
#  [Lap 2] 0.0s -> Rueda,
#  [Lap 3] 34.723487854003906s -> Rueda,
#  [Lap 4] 0.0s -> Arnau,
#  [Lap 5] 37.11188125610352s -> Arnau,
#  [Lap 6] 13.044018745422363s -> Arnau,
#  [Lap 7] 0.0s -> Arnau,
#  [Lap 8] 34.69199752807617s -> Arnau,
#  [Lap 9] 0.0s -> Boix,
#  [Lap 10] 0.0s -> Boix,
#  [Lap 11] 34.57621765136719s -> Boix,
#  [Lap 12] 0.0s -> Gil,
#  [Lap 13] 35.06794738769531s -> Gil,
#  [Lap 14] 0.0s -> Gil,
#  [Lap 15] 33.851070404052734s -> Gil,
#  [Lap 16] 0.0s -> Rodas,
#  [Lap 17] 34.506587982177734s -> Rodas,
#  [Lap 18] 0.0s -> Rodas,
#  [Lap 19] 32.751953125s -> Rodas,
#  [Lap 20] 0s -> Rodas,
#  [Lap 21] 0.0s -> Jordi,
#  [Lap 22] 34.496070861816406s -> Jordi]

# %%
run.laps[14].steering.chart() & run.laps[2].throttle.chart()
# Out:
# /usr/local/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %%
run.laps[14].steering.difference_chart() & run.laps[2].throttle.difference_chart()
# Out:
# /usr/local/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %%
run.steering_smoothness_chart()
# Out:
# /usr/local/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
run.throttle_smoothness_chart()
# Out:
# /usr/local/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)
